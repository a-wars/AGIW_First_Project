# %%
# %matplotlib inline
# Importing libraries
import matplotlib.pyplot as plt
import pandas as pd

FILEPATH_PREFIX = '../../../book_crawler/data'
SPIDERNAME = 'powells'
FILENAME = '2019-05-14T20-37-16.csv'
FILEPATH = '{}/{}/{}'.format(FILEPATH_PREFIX, SPIDERNAME, FILENAME)
FILEPATH
# Out:
# '../../../book_crawler/data/powells/2019-05-14T20-37-16.csv'

# %%
df = pd.read_csv(FILEPATH)

# %% [markdown]
# ## Data analisys
# Some preliminary analisys of the dataset

# %%
print("First 5 rows")
print("------------")
df.head()
# Out:
# First 5 rows
# ------------
#                                                  url  \
# 0  https://www.powells.com/blog/author/kristen-ar...
# 1   https://www.powells.com/blog/category/interviews
# 2            https://www.powells.com/nonfiction-sale
# 3           https://www.powells.com/powells-presents
# 4                  https://www.powells.com/locations
#
#                 referer_url                                                src
# 0  https://www.powells.com/  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 1  https://www.powells.com/  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 2  https://www.powells.com/  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 3  https://www.powells.com/  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 4  https://www.powells.com/  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...

# %%
print("No. of rows and columns")
print("-----------------------")
df.shape
# Out:
# No. of rows and columns
# -----------------------
# (10571, 3)

# %%
print("Check null values")
print("-----------------")
df.isnull().any().any()
# Out:
# Check null values
# -----------------
# False

# %%
print("Check duplicate values")
print("----------------------")
len(df['url'].unique()) != df.shape[0]
# Out:
# Check duplicate values
# ----------------------
# False

# %%
print("DataFrame column types")
print("----------------------")
df.info()
# Out:
# DataFrame column types
# ----------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10571 entries, 0 to 10570
# Data columns (total 3 columns):
# url            10571 non-null object
# referer_url    10571 non-null object
# src            10571 non-null object
# dtypes: object(3)
# memory usage: 247.8+ KB

# %%
print("Some stats")
print("----------------")
df.describe()
# Out:
# Some stats
# ----------------
#                                                       url  \
# count                                               10571
# unique                                              10571
# top     https://www.powells.com/login?returnurl=%2fboo...
# freq                                                    1
#
#                                               referer_url  \
# count                                               10571
# unique                                               6556
# top     https://www.powells.com/ProductMoreIsbn?produc...
# freq                                                   28
#
#                                                       src
# count                                               10571
# unique                                              10571
# top     <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# freq                                                    1

# %% [markdown]
# ## Data cleaning
# During the crawling phase (using Scrapy), we restrained the crawled pages to be only the web pages matching with `www.powells.com` domain.

# %%
import re

# %%
blackwellsRegex = r'^https\:\/\/www\.powells\.com'

# %%
otherDomainsDataFrame = df[- df['url'].str.match(blackwellsRegex)]

# %%
otherDomainsDataFrame.head()
# Out:
# Empty DataFrame
# Columns: [url, referer_url, src]
# Index: []

# %% [markdown]
# So Scrapy effectively crawled only pages from the `www.powells.com` domain

# %% [markdown]
# ## Add `shingle_vector` label
# Compute shingle vector for each page of the dataframe

# %%
#add top level folder to sys.path
import sys
sys.path.append('../../../')

from foxlink_clustering.clustering.shingler import compute_shingle_vector

# %%
src = df.iloc[0]['src']

# %% [markdown]
# The default value for window size in Foxlink is 3

# %%
DEFAULT_WINDOW_SIZE = 3
result = compute_shingle_vector(src, DEFAULT_WINDOW_SIZE)

# %%
result
# Out:
# (7, 2, 1, 8, 3, 10, 0, 5)

# %% [markdown]
# Set `shingle_vector` label for each row

# %%
df['shingle_vector'] = df.apply(lambda x: compute_shingle_vector(x['src'], DEFAULT_WINDOW_SIZE), axis=1)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.powells.com/blog/author/kristen-ar...
# 1   https://www.powells.com/blog/category/interviews
# 2            https://www.powells.com/nonfiction-sale
# 3           https://www.powells.com/powells-presents
# 4                  https://www.powells.com/locations
#
#                 referer_url  \
# 0  https://www.powells.com/
# 1  https://www.powells.com/
# 2  https://www.powells.com/
# 3  https://www.powells.com/
# 4  https://www.powells.com/
#
#                                                  src  \
# 0  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 1  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 3  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 4  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
#
#               shingle_vector
# 0  (7, 2, 1, 8, 3, 10, 0, 5)
# 1   (2, 1, 1, 0, 3, 5, 0, 1)
# 2   (0, 2, 2, 8, 3, 0, 0, 0)
# 3   (0, 2, 2, 8, 1, 1, 0, 0)
# 4   (2, 0, 0, 4, 2, 2, 0, 0)

# %% [markdown]
# ## Write dataset to a file

# %%
df.to_csv('../../../datasets/powells.csv', encoding='utf-8', index=False)

# %%
test = pd.read_csv('../../../datasets/powells.csv')

# %%
test.head()
# Out:
#                                                  url  \
# 0  https://www.powells.com/blog/author/kristen-ar...
# 1   https://www.powells.com/blog/category/interviews
# 2            https://www.powells.com/nonfiction-sale
# 3           https://www.powells.com/powells-presents
# 4                  https://www.powells.com/locations
#
#                 referer_url  \
# 0  https://www.powells.com/
# 1  https://www.powells.com/
# 2  https://www.powells.com/
# 3  https://www.powells.com/
# 4  https://www.powells.com/
#
#                                                  src  \
# 0  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 1  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 3  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 4  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
#
#               shingle_vector
# 0  (7, 2, 1, 8, 3, 10, 0, 5)
# 1   (2, 1, 1, 0, 3, 5, 0, 1)
# 2   (0, 2, 2, 8, 3, 0, 0, 0)
# 3   (0, 2, 2, 8, 1, 1, 0, 0)
# 4   (2, 0, 0, 4, 2, 2, 0, 0)

# %%
test.shape
# Out:
# (10571, 4)
